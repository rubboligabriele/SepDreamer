# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

PATH = "../../data/intermediates/patient_states/patient_states.csv"

# %%
df = pd.read_csv(PATH)

print(df.shape)
df.head()

print(df.notna().sum(axis=1).describe())

print(df.isna().mean().sort_values(ascending=False))

print("HR availability:", df["HR"].notna().mean())
# Out:
# (3316332, 68)
# count    3.316332e+06
# mean     3.151699e+00
# std      5.295143e-01
# min      3.000000e+00
# 25%      3.000000e+00
# 50%      3.000000e+00
# 75%      3.000000e+00
# max      5.000000e+00
# dtype: float64
# Sodium        1.000000
# Hb            1.000000
# BUN           1.000000
# Creatinine    1.000000
# Magnesium     1.000000
#                 ...
# extubated     0.924151
# mechvent      0.924151
# timestep      0.000000
# icustayid     0.000000
# bloc          0.000000
# Length: 68, dtype: float64
# HR availability: 0.0
